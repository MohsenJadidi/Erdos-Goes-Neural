# %% [markdown]
# ## First take care of all imports

# %%
import os
import pickle
import torch
import torch.nn.functional as F
from torch.nn import Linear
from kernel.datasets import get_dataset
import time
from torch import tensor
from torch.optim import Adam
from torch.optim import SGD
from torch_geometric.data import DataLoader, DenseDataLoader as DenseLoader
from math import ceil
from torch.nn import Linear
from torch.distributions import categorical
from torch.distributions import Bernoulli
import torch.nn
# %matplotlib inline
from matplotlib import pyplot as plt
import pygraphviz as pgv
from torch_geometric.utils import convert as cnv
from torch_geometric.utils import sparse as sp
from torch_geometric.data import Data
import pygraphviz as pgv
from networkx.drawing.nx_agraph import graphviz_layout
import networkx as nx
from torch.utils.data.sampler import RandomSampler
from torch.nn.functional import gumbel_softmax
from torch.distributions import relaxed_categorical
from torch_geometric.nn.inits import uniform
from torch_geometric.nn.inits import glorot, zeros
from torch.nn import Parameter
from torch.nn import Sequential as Seq, Linear, ReLU
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import degree
from torch_geometric.nn import GINConv, GATConv
from torch.nn import Parameter
from torch.nn import Sequential as Seq, Linear, ReLU, LeakyReLU
from torch_geometric.nn import MessagePassing
from torch.nn import Linear, Sequential, ReLU, BatchNorm1d as BN
from torch_geometric.utils import scatter_
from torch_geometric.data import Batch 
from torch_scatter import scatter_min, scatter_max, scatter_add, scatter_mean
from torch import autograd
from torch_geometric.utils import softmax, add_self_loops, remove_self_loops, segregate_self_loops, remove_isolated_nodes, contains_isolated_nodes, add_remaining_self_loops
from models import cut_MPNN
from modules_and_utils import derandomize_cut, GATAConv,get_diracs
import scipy
import scipy.io
import GPUtil

# %% [markdown]
# ## Prepare dataset

# %%
datasets = ["facebook", "sf","twitter"]
curr_dataset= datasets[0] 
#set random seed
rseed = 201

if curr_dataset=="facebook":
    datasetname = "facebook_graphs"
    dataset = []
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    #set up facebook data 
    upper_limit = 15000
    lower_limit = 0
    path_to_facebook_dataset= "%PATH"
        for file in os.listdir(path_to_facebook_dataset):
            if file.endswith(".mat"):
                adj_matrix = scipy.io.loadmat(path_to_facebook_dataset+str(file))
                edge_index = from_scipy_sparse_matrix(adj_matrix['A'])[0]
                x = torch.ones(adj_matrix['local_info'].shape[0])
                if (adj_matrix['local_info'].shape[0] < lower_limit) or (adj_matrix['local_info'].shape[0] > upper_limit):
                    continue
                data_temp = Batch(x = x, edge_index = edge_index.long(), batch = torch.zeros_like(x).long())
                data_proper = get_diracs(data_temp.to('cuda'), 1, sparse = True)
                r,c = data_proper.edge_index
                data = Batch(x = data_temp.x, edge_index = data_temp.edge_index)
                degrees = degree(r, adj_matrix['local_info'].shape[0])
                print("Graph specs: ")
                print("number of nodes: ", adj_matrix['A'].shape[0])
                print("average degree: ", degrees.mean(0))
                print("total volume: ", data_proper.total_vol)
                print("-------------")
                dataset += [data]

else if curr_dataset=="sf":
    datasetname = "SF-295"
    dataset = get_dataset(datasetname,sparse=1)

else if curr_dataset=="twitter"
    path_to_twitter_dataset = "%PATH"
    stored_dataset = open(path_to_twitter_dataset, 'rb')        
    dataset = pickle.load(stored_dataset)    

dataset_scale = 1.
total_samples = int(np.floor(len(dataset)*dataset_scale))
dataset = dataset[:total_samples]

num_trainpoints = int(np.floor(0.6*len(dataset)))
num_valpoints = int(np.floor(num_trainpoints/3))
num_testpoints = len(dataset) - (num_trainpoints + num_valpoints)


traindata= dataset[0:num_trainpoints]
valdata = dataset[num_trainpoints:num_trainpoints + num_valpoints]

testdata = dataset[num_trainpoints + num_valpoints:]

batch_size = 32
train_loader = DataLoader(traindata, batch_size, shuffle=True)
test_loader = DataLoader(testdata, batch_size, shuffle=False)
val_loader =  DataLoader(valdata, batch_size, shuffle=False)


#set up random seed 
torch.manual_seed(rseed)
np.random.seed(2)   
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Graph specs:
# number of nodes:  6386
# average degree:  tensor(69.1685, device='cuda:0')
# total volume:  tensor([441710.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6596
# average degree:  tensor(89.9388, device='cuda:0')
# total volume:  tensor([593236.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6440
# average degree:  tensor(79.0286, device='cuda:0')
# total volume:  tensor([508944.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6472
# average degree:  tensor(83.3171, device='cuda:0')
# total volume:  tensor([539228.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  4087
# average degree:  tensor(91.4468, device='cuda:0')
# total volume:  tensor([373743.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2970
# average degree:  tensor(66.4094, device='cuda:0')
# total volume:  tensor([197236.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3898
# average degree:  tensor(71.5834, device='cuda:0')
# total volume:  tensor([279032.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7752
# average degree:  tensor(74.2503, device='cuda:0')
# total volume:  tensor([575588.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2920
# average degree:  tensor(62.5836, device='cuda:0')
# total volume:  tensor([182744.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6682
# average degree:  tensor(75.7465, device='cuda:0')
# total volume:  tensor([506138.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  5180
# average degree:  tensor(73.0409, device='cuda:0')
# total volume:  tensor([378352.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  5075
# average degree:  tensor(79.1663, device='cuda:0')
# total volume:  tensor([401769.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  12155
# average degree:  tensor(90.0726, device='cuda:0')
# total volume:  tensor([1094833.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  10521
# average degree:  tensor(117.1317, device='cuda:0')
# total volume:  tensor([1232343.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3482
# average degree:  tensor(90.0540, device='cuda:0')
# total volume:  tensor([313568.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  8069
# average degree:  tensor(107.0434, device='cuda:0')
# total volume:  tensor([863733.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2613
# average degree:  tensor(86.7222, device='cuda:0')
# total volume:  tensor([226605.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  769
# average degree:  tensor(44.3186, device='cuda:0')
# total volume:  tensor([34081.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  8578
# average degree:  tensor(95.5325, device='cuda:0')
# total volume:  tensor([819478.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3068
# average degree:  tensor(78.6799, device='cuda:0')
# total volume:  tensor([241390.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3593
# average degree:  tensor(77.8355, device='cuda:0')
# total volume:  tensor([279663.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  9895
# average degree:  tensor(103.3632, device='cuda:0')
# total volume:  tensor([1022779.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2790
# average degree:  tensor(81.9935, device='cuda:0')
# total volume:  tensor([228762.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  8991
# average degree:  tensor(50.9575, device='cuda:0')
# total volume:  tensor([458159.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  1446
# average degree:  tensor(83.4191, device='cuda:0')
# total volume:  tensor([120624.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  1659
# average degree:  tensor(74.5986, device='cuda:0')
# total volume:  tensor([123759.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2970
# average degree:  tensor(64.9050, device='cuda:0')
# total volume:  tensor([192768.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  8600
# average degree:  tensor(90.4247, device='cuda:0')
# total volume:  tensor([777652.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  4047
# average degree:  tensor(102.2355, device='cuda:0')
# total volume:  tensor([413747.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  13686
# average degree:  tensor(53.7247, device='cuda:0')
# total volume:  tensor([735276.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3578
# average degree:  tensor(85.8222, device='cuda:0')
# total volume:  tensor([307072.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7460
# average degree:  tensor(89.4756, device='cuda:0')
# total volume:  tensor([667488.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  10004
# average degree:  tensor(73.5498, device='cuda:0')
# total volume:  tensor([735792.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  14940
# average degree:  tensor(58.4282, device='cuda:0')
# total volume:  tensor([872918.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  14948
# average degree:  tensor(60.3017, device='cuda:0')
# total volume:  tensor([901390.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  13882
# average degree:  tensor(56.0258, device='cuda:0')
# total volume:  tensor([777750.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  11770
# average degree:  tensor(76.5026, device='cuda:0')
# total volume:  tensor([900436.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  11509
# average degree:  tensor(85.6237, device='cuda:0')
# total volume:  tensor([985443.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  14916
# average degree:  tensor(93.0489, device='cuda:0')
# total volume:  tensor([1387918.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  12803
# average degree:  tensor(107.1965, device='cuda:0')
# total volume:  tensor([1372437.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2252
# average degree:  tensor(75.9441, device='cuda:0')
# total volume:  tensor([171026.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  9069
# average degree:  tensor(54.6436, device='cuda:0')
# total volume:  tensor([495563.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  962
# average degree:  tensor(40.1102, device='cuda:0')
# total volume:  tensor([38586.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  9414
# average degree:  tensor(91.4266, device='cuda:0')
# total volume:  tensor([860690.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7694
# average degree:  tensor(80.0424, device='cuda:0')
# total volume:  tensor([615846.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3075
# average degree:  tensor(82.0472, device='cuda:0')
# total volume:  tensor([252295.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  13746
# average degree:  tensor(65.3349, device='cuda:0')
# total volume:  tensor([898094.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  5372
# average degree:  tensor(104.9430, device='cuda:0')
# total volume:  tensor([563754.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7755
# average degree:  tensor(95.7881, device='cuda:0')
# total volume:  tensor([742837.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2235
# average degree:  tensor(82.3906, device='cuda:0')
# total volume:  tensor([184143.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  11621
# average degree:  tensor(98.8109, device='cuda:0')
# total volume:  tensor([1148281.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3826
# average degree:  tensor(84.0444, device='cuda:0')
# total volume:  tensor([321554.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3445
# average degree:  tensor(89.2479, device='cuda:0')
# total volume:  tensor([307459.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7324
# average degree:  tensor(53.2176, device='cuda:0')
# total volume:  tensor([389766.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  4563
# average degree:  tensor(71.7447, device='cuda:0')
# total volume:  tensor([327371.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  13653
# average degree:  tensor(80.6868, device='cuda:0')
# total volume:  tensor([1101617.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2314
# average degree:  tensor(84.3137, device='cuda:0')
# total volume:  tensor([195102.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  2682
# average degree:  tensor(49.6592, device='cuda:0')
# total volume:  tensor([133186.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  11247
# average degree:  tensor(63.4803, device='cuda:0')
# total volume:  tensor([713963.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  13377
# average degree:  tensor(49.0248, device='cuda:0')
# total volume:  tensor([655805.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6637
# average degree:  tensor(76.3253, device='cuda:0')
# total volume:  tensor([506571.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6833
# average degree:  tensor(46.4652, device='cuda:0')
# total volume:  tensor([317497.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  12193
# average degree:  tensor(78.0160, device='cuda:0')
# total volume:  tensor([951249.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  6591
# average degree:  tensor(64.1476, device='cuda:0')
# total volume:  tensor([422797.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  1518
# average degree:  tensor(44.4625, device='cuda:0')
# total volume:  tensor([67494.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  14070
# average degree:  tensor(70.0212, device='cuda:0')
# total volume:  tensor([985198.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  3748
# average degree:  tensor(44.7049, device='cuda:0')
# total volume:  tensor([167554.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  10567
# average degree:  tensor(93.4268, device='cuda:0')
# total volume:  tensor([987241.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  14935
# average degree:  tensor(65.5764, device='cuda:0')
# total volume:  tensor([979383.], device='cuda:0')
# -------------
# Graph specs:
# number of nodes:  7772
# average degree:  tensor(82.0574, device='cuda:0')
# total volume:  tensor([637750.], device='cuda:0')
# -------------

# %% [markdown]
# ## TRAIN MODEL

# %%
def predict(model, data_loader, recfield):
    net.eval()
    avg_loss = 0
    for data in data_loader:
        optimizer.zero_grad()
        data = data.to(device)
        data = get_diracs(data, 1, sparse = True, effective_volume_range=0.15, receptive_field = recfield)
        data = data.to(device)
        retdict = net(data)
        avg_loss += retdict['loss'][0].item()/len(data_loader)

    return avg_loss

# %%
epochs=150
numlayers=6
elasticity = 0.25
receptive_field= numlayers + 1
val_losses = []

#for sf/twitter
#net =  cut_MPNN(dataset,numlayers, 64, 64,1, elasticity = elasticity)

#for faceboook
net =  cut_MPNN(dataset,6, 256, 24,1, elasticity = 0.25)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lr_decay_step_size = 5
lr_decay_factor = 0.95

net.to(device).reset_parameters()
optimizer = Adam(net.parameters(), lr=0.0001, weight_decay=0.00)
net.train()
retdict = {}
path_to_save = "%PATH"
for epoch in range(epochs):
    totalretdict = {}
    count=0
    if epoch % 15 == 0:
        val_losses += [predict(net, val_loader, receptive_field)]
        if epoch>20:
            if (val_losses[-1] > val_losses[-2]) and (val_losses[-1] > val_losses[-3]) and (epoch>100):
                print("Converged!")
                if val_losses[-2] < val_losses[-3]:
                    file_name = path_to_save+ str(datasetname)+ '/' + str(net)+ '_'+ str(epoch-15)+'_samples2'
                    net.load_state_dict(torch.load(file_name), strict=False)
                else:
                    file_name = path_to_save+ str(datasetname)+ '/' + str(net)+ '_'+ str(epoch-30)+'_samples2'
                    net.load_state_dict(torch.load(file_name), strict=False)
                break
            file_name = path_to_save + str(datasetname)+ '/' + str(net)+ '_'+ str(epoch)+'_samples2'
            print("file_name: ", file_name)
            torch.save({file_name : net.state_dict()},  file_name)
    
    #learning rate schedule
    if epoch % lr_decay_step_size == 0:
        for param_group in optimizer.param_groups:
                    param_group['lr'] = lr_decay_factor * param_group['lr']
   
    net.train()
    for data in train_loader:
        count += 1 
        optimizer.zero_grad(), 
        data = data.to(device)
        data_prime = get_diracs(data, 1, sparse = True, effective_volume_range=0.15, receptive_field = receptive_field)
        data = data.to('cpu')
        data_prime = data_prime.to(device)  
        retdict = net(data_prime)
        for key,val in retdict.items():
            if "sequence" in val[1]:
                if key in totalretdict:
                    totalretdict[key][0] += val[0].item()
                else:
                    totalretdict[key] = [val[0].item(),val[1]]
        
        if epoch > 0:
                retdict["loss"][0].backward()
                torch.nn.utils.clip_grad_norm_(net.parameters(),1)
                optimizer.step()                   

        del data_prime

# %% [markdown]
# ## EVALUATE

# %%
#initialize
net.eval()
rcuts =  {}
rvols =  {}
rconds = {}
mcuts =  []
mvols =  []
mconds = []
best_cuts =  []
best_vols =  []
best_conds = []
count = 0

#select number of diracs
num_diracs = 100


cuts = torch.zeros((num_data_points, num_diracs))
conds =  torch.zeros((num_data_points, num_diracs))
vols =  torch.zeros((num_data_points, num_diracs))
randtargets = torch.zeros((num_data_points, num_diracs))
best_sets = {}
totalvols = []



t_0 = time.time()
with torch.no_grad():
    for data2 in test_loader:
        batch = data2.batch
        
        count += 1
           
        print("Batch count: ", count)
        dirac_count = 0 
        for dirac in range(num_diracs):
            data2 = data2.to(device)            
            data_new = get_diracs(data2, 1, sparse=True, effective_volume_range=0.2)            
            
            feasible_vols = (data_new.recfield_vol/data_new.total_vol)*0.85
            target_vol = torch.rand_like(feasible_vols, device=device)*feasible_vols + 0.1
            data_new = data_new.to(device) 
            retdict2 = net(data_new, target_vol)
            netprobs = retdict2['output'][0]
            batch_new = data_new.batch
            num_graphs = batch_new.max().item() + 1
            e_i = data_new.edge_index 
            r,c = e_i
            deg = degree(r)
            bestcond = torch.ones(num_graphs)
            bestcut = 1000*torch.ones(num_graphs)
            bestvol = torch.zeros(num_graphs)
            outp =  derandomize_cut(data_new.to('cuda'), netprobs.cuda(), target_vol.cuda()*data_new.total_vol.cuda(), elasticity=0.25, draw=False)
            tv_hard = total_var(outp, data_new.edge_index.cuda(), data_new.batch.cuda())
            vol_hard = scatter_add(deg*outp, batch_new, 0, dim_size = batch_new.max().item()+1)
            mycond = tv_hard/vol_hard
            conds[(count-1)*tbatch_size:count*batch_size, dirac] = mycond
            cuts[(count-1)*tbatch_size:count*batch_size, dirac] = tv_hard
            vols[(count-1)*tbatch_size:count*batch_size, dirac] = vol_hard
            randtargets[(count-1)*tbatch_size:count*batch_size, dirac] = target_vol.cpu()*data_new.total_vol.cpu()          
            dirac_count += 1
t_final = time.time() - t_0
print(f"average time per graph: {t_final/len(testdata)}")
# Out:
# Batch count:  1
# Batch count:  2
# Batch count:  3
# Batch count:  4
# Batch count:  5
# Batch count:  6
# Batch count:  7
# Batch count:  8
# Batch count:  9
# Batch count:  10
# Batch count:  11
# Batch count:  12
# Batch count:  13
# Batch count:  14
# average time per graph: 289.2852131979806

# %% [markdown]
# ## Print out mean conductance +/- std

# %%
meanconds = conds.mean(0)
print(f"meanconds: {meanconds.mean()} +/- {meanconds.std()}")
# Out:
# meanconds: 0.1568647176027298 +/- 0.026729123666882515
